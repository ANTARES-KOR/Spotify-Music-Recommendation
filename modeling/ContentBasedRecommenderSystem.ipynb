# %% [markdown]
# # Basic Setting

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import random
import warnings
warnings.filterwarnings(action='ignore')

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
track = pd.read_csv('global_track_spotify.csv')
track = pd.DataFrame(track)
track.head()
# Out:
#    Unnamed: 0                      id   artist_name  \
# 0           0  4Dvkj6JhhA12EX05fT7y2e  Harry Styles
# 1           1  75FEaRjZTKLhTrFGsfMUXR     Kate Bush
# 2           2  6Sq7ltF9Qa7SNFBsV5Cogx     Bad Bunny
# 3           3  6xGruZOHLs39ZbVccQTuPZ          Joji
# 4           4  3k3NWokhRRkEPhCzPmV8TW     Bad Bunny
#
#                                track_name        album_name  \
# 0                               As It Was     Harry's House
# 1  Running Up That Hill (A Deal With God)    Hounds Of Love
# 2                         Me Porto Bonito  Un Verano Sin Ti
# 3                           Glimpse of Us     Glimpse of Us
# 4                           Ojitos Lindos  Un Verano Sin Ti
#
#                                         artist_genre  artist_popularity  \
# 0                                            ['pop']                 94
# 1  ['art pop', 'art rock', 'baroque pop', 'new wa...                 80
# 2              ['latin', 'reggaeton', 'trap latino']                100
# 3                   ['alternative r&b', 'viral pop']                 81
# 4              ['latin', 'reggaeton', 'trap latino']                100
#
#    track_popularity  artist_followers  danceability  ...  key  loudness  \
# 0                93          21396163        167303  ...    6    -5.338
# 1                94           1106089        298933  ...   10   -13.123
# 2                98          49880269        178567  ...    1    -5.105
# 3                89           5992900        233456  ...    8    -9.258
# 4                98          49880269        258299  ...    3    -5.745
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0557        0.3420          0.001010    0.3110    0.662  173.930
# 1       0.0550        0.7200          0.003140    0.0604    0.197  108.375
# 2       0.0817        0.0901          0.000027    0.0933    0.425   92.005
# 3       0.0531        0.8910          0.000005    0.1410    0.268  169.914
# 4       0.0413        0.0800          0.000001    0.5280    0.268   79.928
#
#    duration_ms  time_signature
# 0       167303               4
# 1       298933               4
# 2       178567               4
# 3       233456               3
# 4       258299               4
#
# [5 rows x 21 columns]

# %% [markdown]
# # Feature Engineering

# %%
import re
 
def cleanText(readData):
    text = re.sub('[-=+#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','', readData) # 쉼표(,) 뺌
 
    return text

# %%
genre = []
for i in track['artist_genre']:
    if i == '[]':
        i = 'NA'
        genre.append(i.strip()) #"'[]'"
    else:
        i = cleanText(i)
        genre.append(i.strip())
track['genre'] = genre

# %%
track['track_popularity'] = track['track_popularity'] / 100

# %%
track.head()
# Out:
#    Unnamed: 0                      id   artist_name  \
# 0           0  4Dvkj6JhhA12EX05fT7y2e  Harry Styles
# 1           1  75FEaRjZTKLhTrFGsfMUXR     Kate Bush
# 2           2  6Sq7ltF9Qa7SNFBsV5Cogx     Bad Bunny
# 3           3  6xGruZOHLs39ZbVccQTuPZ          Joji
# 4           4  3k3NWokhRRkEPhCzPmV8TW     Bad Bunny
#
#                                track_name        album_name  \
# 0                               As It Was     Harry's House
# 1  Running Up That Hill (A Deal With God)    Hounds Of Love
# 2                         Me Porto Bonito  Un Verano Sin Ti
# 3                           Glimpse of Us     Glimpse of Us
# 4                           Ojitos Lindos  Un Verano Sin Ti
#
#                                         artist_genre  artist_popularity  \
# 0                                            ['pop']                 94
# 1  ['art pop', 'art rock', 'baroque pop', 'new wa...                 80
# 2              ['latin', 'reggaeton', 'trap latino']                100
# 3                   ['alternative r&b', 'viral pop']                 81
# 4              ['latin', 'reggaeton', 'trap latino']                100
#
#    track_popularity  artist_followers  danceability  ...  loudness  \
# 0              0.93          21396163        167303  ...    -5.338
# 1              0.94           1106089        298933  ...   -13.123
# 2              0.98          49880269        178567  ...    -5.105
# 3              0.89           5992900        233456  ...    -9.258
# 4              0.98          49880269        258299  ...    -5.745
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0557        0.3420          0.001010    0.3110    0.662  173.930
# 1       0.0550        0.7200          0.003140    0.0604    0.197  108.375
# 2       0.0817        0.0901          0.000027    0.0933    0.425   92.005
# 3       0.0531        0.8910          0.000005    0.1410    0.268  169.914
# 4       0.0413        0.0800          0.000001    0.5280    0.268   79.928
#
#    duration_ms  time_signature  \
# 0       167303               4
# 1       298933               4
# 2       178567               4
# 3       233456               3
# 4       258299               4
#
#                                                genre
# 0                                                pop
# 1  art pop, art rock, baroque pop, new wave pop, ...
# 2                      latin, reggaeton, trap latino
# 3                          alternative rb, viral pop
# 4                      latin, reggaeton, trap latino
#
# [5 rows x 22 columns]

# %% [markdown]
# # Music Recommeder System

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

class ContentTFIDF:
    
    def __init__(self, data):
        self.data = data

    def calculateTFIDF(self):
        tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1,2) ,stop_words=stopwords.words('english'))
        tfidf_content = tfidf.fit_transform(self.data['artist_name'] + ' ' +
                                       self.data['track_name'] + ' ' +
                                       self.data['album_name'] + ' ' +
                                       self.data['genre'])
        return tfidf_content

# %%
track.shape
# Out:
# (1154, 22)

# %%
ct = ContentTFIDF(track)
ct_tfidf = ct.calculateTFIDF()
ct_tfidf
# Out:
# <1154x7880 sparse matrix of type '<class 'numpy.float64'>'
# 	with 18739 stored elements in Compressed Sparse Row format>

# %%
ct_tfidf.shape
# Out:
# (1154, 7880)

# %%
class ContentBasedRecommenderSystem:
    
    def __init__(self, data, tfidf_matrix):
        self.data = data
        self.tfidf_matrix = tfidf_matrix
        self.music = ''
        self.mood = ''
        self.speed = ''
        self.emotion = ''

        
    def user_info(self):
        print("--------------------------------------------------------------------\n\
노래를 추천해드리기 전에 잠시 당신에 대해서 알아보겠습니다 \n\
--------------------------------------------------------------------")
        songs = list(self.data['track_name'].values)
        song = random.sample(songs, 5)

        total_dictionary = {}
        qs=[]
        qs.append("무슨 곡이 가장 좋아요?   1) {}  2) {}  3) {}  4) {}  5) {}".format(song[0],song[1],song[2],song[3],song[4]))
        qs.append("어떤 분위기의 곡을 좋아하세요?   1) 밝은  2) 어두운")
        qs.append("어느정도의 속도를 가직 곡을 좋아하시나요?   1) 빠름  2) 느림")
        qs.append("고객님께서는 현재 감정이 어떤 상태이신가요?   1) 신남  2) 평범  3) 슬픔")
        qs.append("끝")

        for q in qs:
            question = q
            if question == "끝":
                break
            else:
                total_dictionary[question] = ""

        for i in total_dictionary:
            print(i)
            answer = input()
            total_dictionary[i] = answer 

        a = list(total_dictionary.items())
        self.music = a[0][1]
        self.mood = int(a[1][1])
        self.speed = int(a[2][1])
        self.emotion = int(a[3][1])
        
        return [self.music, self.mood, self.speed, self.emotion]

    def get_genre_score(self):
        cosine_sim_score = cosine_similarity(self.tfidf_matrix, self.tfidf_matrix)
        target_genre_index = self.data[self.data['track_name'] == self.music].index.values
        genre_score = cosine_sim_score[target_genre_index, :].reshape(-1, 1)
        return genre_score

    def get_mood_score(self):
        temp = pd.DataFrame(self.data['valence'])
        if self.mood == 1:
            temp['mood_score'] = temp['valence']
        else:
            temp['mood_score'] = temp['valence'].apply(lambda x: 1-x)
        return temp['mood_score']
    
    def get_speed_score(self):
        temp = pd.DataFrame(self.data['tempo'])
        temp['tempo_scaled'] = MinMaxScaler().fit_transform(pd.DataFrame(temp['tempo']))
        if self.speed == 1:
            temp['speed_score'] = temp['tempo_scaled']
        else:
            temp['speed_score'] = temp['tempo_scaled'].apply(lambda x: 1-x)
        return temp['speed_score']

    def get_emotion_score(self):
        temp = self.data[['danceability', 'energy', 'acousticness']]
        temp['danceability_scaled'] = MinMaxScaler().fit_transform((pd.DataFrame(temp['danceability'])))
        temp['acousticness_reverse'] = temp['acousticness'].apply(lambda x: 1-x)
        if self.emotion == 1:
            temp['emotion_score'] = temp.apply(lambda x: 1/3 * (x['danceability_scaled'] + x['energy'] + x['acousticness_reverse']), axis = 1)
        elif self.emotion == 2:
            temp['emotion_score'] = temp.apply(lambda x: 2/3 * (abs(x['danceability_scaled']-0.5) + abs(x['energy']-0.5) + abs(x['acousticness_reverse']-0.5)), axis = 1)
        else:
            temp['emotion_score'] = temp.apply(lambda x: 1/3 * ((1-x['danceability_scaled']) + (1-x['energy']) + (1-x['acousticness_reverse'])), axis = 1)
        return temp['emotion_score']

    def get_total_score(self, top_n = 20):
        result_df = self.data[['artist_name', 'track_name', 'album_name']]
        result_df['mood_score'] = pd.DataFrame(self.get_mood_score())
        result_df['speed_score'] = pd.DataFrame(self.get_speed_score())
        result_df['emotion_score'] = pd.DataFrame(self.get_emotion_score())
        result_df['genre_score'] = pd.DataFrame(self.get_genre_score())
        result_df['total_score'] = result_df.apply(lambda x: 1/6*(x['mood_score'] + x['speed_score'] + x['emotion_score']) + 0.5*x['genre_score'], axis = 1)

        return result_df.sort_values(by = 'total_score', ascending=False)[:top_n]

# %%
cbr = ContentBasedRecommenderSystem(track, ct_tfidf)
ui1 = cbr.user_info()
ex1 = cbr.get_total_score()
ex1
# Out:
# --------------------------------------------------------------------
# 노래를 추천해드리기 전에 잠시 당신에 대해서 알아보겠습니다
# --------------------------------------------------------------------
# 무슨 곡이 가장 좋아요?   1) Look To The Sky  2) So Fresh  3) START OVER  4) Bambi  5) 무기여 잘 있거라
# So Fresh
# 어떤 분위기의 곡을 좋아하세요?   1) 밝은  2) 어두운
# 1
# 어느정도의 속도를 가직 곡을 좋아하시나요?   1) 빠름  2) 느림
# 1
# 고객님께서는 현재 감정이 어떤 상태이신가요?   1) 신남  2) 평범  3) 슬픔
# 1
#            artist_name                                  track_name  \
# 792            MC MONG                                    So Fresh
# 826            MC MONG                      A Letter to you Part.2
# 189                AOA                                  Like a Cat
# 375                황혜영                                    일과 이분의 일
# 857                BoA                                  My Sweetie
# 279          Epik High                                         Fan
# 70        Mighty Mouth  TOK TOK (ORIGINAL VER.) (feat.Kim Bum Soo)
# 819           The Jadu                                          김밥
# 80              Secret                                Love Is Move
# 204         Girl's Day                                Ring My Bell
# 437         Kim Gun Mo             One Flew over the Cuckoo's Nest
# 298   Brown Eyed Girls                             오아시스 (feat.이재훈)
# 414             DJ DOC                              Dance with DOC
# 610              BOBBY                                   Let iT Go
# 68              Secret                                     Shy Boy
# 969           Jay Park                        좋아 Joah (Remastered)
# 389               COOL                                          운명
# 1107       Do&Be Sound                                    Eollebit
# 352                YTC                                           정
# 344       SUPER JUNIOR                          쏘리 쏘리 Sorry, Sorry
#
#                               album_name  mood_score  speed_score  \
# 792                             So Fresh       0.807     0.548033
# 826                         The Way I Am       0.705     0.480299
# 189                           Like a Cat       0.928     0.962276
# 375                  투유 프로젝트 - 슈가맨 Pt.33       0.923     0.970206
# 857                 No.1 - The 2nd Album       0.923     0.932434
# 279             Remapping the Human Soul       0.780     0.797894
# 70                          Mighty Fresh       0.875     0.624904
# 819                           The Jadu 3       0.886     0.894518
# 80                      MOVING IN SECRET       0.963     0.773430
# 204         Girl's Day Love Second Album       0.811     0.952116
# 437                               Myself       0.961     0.711348
# 298                              떠나라 미스김       0.783     0.931454
# 414                    DJ. DOC 4th Album       0.982     0.648882
# 610                            LUCKY MAN       0.774     0.903184
# 68                               Shy Boy       0.858     0.836296
# 969                            Evolution       0.731     0.826044
# 389                            Cool Best       0.926     0.673182
# 1107                BGM Jazz Library_264       0.927     0.768855
# 352                                 1집-정       0.971     0.639318
# 344   쏘리 쏘리 Sorry, Sorry - The 3rd Album       0.962     0.624548
#
#       emotion_score  genre_score  total_score
# 792        0.726323     1.000000     0.846893
# 826        0.567021     0.368955     0.476531
# 189        0.723262     0.000000     0.435590
# 375        0.701478     0.000000     0.432447
# 857        0.733024     0.000000     0.431410
# 279        0.708519     0.081803     0.421970
# 70         0.713554     0.106086     0.421953
# 819        0.728663     0.000000     0.418197
# 80         0.743597     0.000000     0.413338
# 204        0.701644     0.000000     0.410793
# 437        0.745615     0.007716     0.406852
# 298        0.692491     0.000000     0.401157
# 414        0.715875     0.019455     0.400853
# 610        0.723867     0.000000     0.400175
# 68         0.680444     0.000000     0.395790
# 969        0.623256     0.062679     0.394723
# 389        0.760802     0.000000     0.393331
# 1107       0.662840     0.000000     0.393116
# 352        0.746985     0.000000     0.392884
# 344        0.767207     0.000000     0.392293

# %%
ui2 = cbr.user_info()
ex2 = cbr.get_total_score()
ex2
# Out:
# --------------------------------------------------------------------
# 노래를 추천해드리기 전에 잠시 당신에 대해서 알아보겠습니다
# --------------------------------------------------------------------
# 무슨 곡이 가장 좋아요?   1) Lonely  2) Yeosu Night Sea  3) 미인아 Bonamana  4) Um Oh Ah Yeh  5) Sherlock (Clue + Note)
# Yeosu Night Sea
# 어떤 분위기의 곡을 좋아하세요?   1) 밝은  2) 어두운
# 2
# 어느정도의 속도를 가직 곡을 좋아하시나요?   1) 빠름  2) 느림
# 2
# 고객님께서는 현재 감정이 어떤 상태이신가요?   1) 신남  2) 평범  3) 슬픔
# 3
#               artist_name                               track_name  \
# 112         Busker Busker                          Yeosu Night Sea
# 107         Busker Busker                    Cherry Blossom Ending
# 111         Busker Busker                               First Love
# 133         Busker Busker                                    Bloom
# 337                  2NE1                                     Fire
# 338                  2NE1                             I Don't Care
# 336                  2NE1  Lollipop (Bonus Track) [BIGBANG & 2NE1]
# 594                JAURIM                                  영원히 영원히
# 1106              Ann kim                                     Home
# 1093                92914                                Starlight
# 829             Johan Kim                                그때로 돌아가는게
# 834        Lee Seung Chul                      인연 (From. "드라마 불새")
# 1085                   IU                        Through the Night
# 1018                ALEPH                       No One Told Me Why
# 973       BROWN EYED SOUL                           Nothing Better
# 569   James Newton Howard                         The Hanging Tree
# 257           J-M Bernard                              Untouchable
# 1047          Summer Soul                             My Last Teen
# 161           M.C the Max                           Because of you
# 806         Sung Si Kyung                                   외워 두세요
#
#                                              album_name  mood_score  \
# 112                                   Busker Busker 1st      0.7730
# 107                                   Busker Busker 1st      0.3370
# 111                                   Busker Busker 1st      0.3140
# 133                                   Busker Busker 1st      0.1520
# 337                                      1st Mini Album      1.0000
# 338                                      1st Mini Album      1.0000
# 336                                      1st Mini Album      1.0000
# 594                                                 자우림      0.8550
# 1106                                               Home      0.8920
# 1093                                          Starlight      0.9220
# 829                                       2gether 4ever      0.9179
# 834                                                  인연      0.8950
# 1085                                  Through the Night      0.7180
# 1018                                                  1      0.8730
# 973                         The Wind, The Sea, The Rain      0.7120
# 569   The Hunger Games: Mockingjay Pt. 1 (Original M...      0.8550
# 257   Piano Romantique, Musique pour Amoureux, Roman...      0.9644
# 1047                                       My Last Teen      0.7700
# 161                      Girl Who Sees Smell OST Part.5      0.8120
# 806                         Double Life; The Other Side      0.8320
#
#       speed_score  emotion_score  genre_score  total_score
# 112      0.042641       0.474897     1.000000     0.715090
# 107      0.423480       0.558160     0.747612     0.593579
# 111      0.423648       0.368484     0.793068     0.580889
# 133      0.423471       0.361034     0.810571     0.561370
# 337      1.000000       0.666667     0.031669     0.460279
# 338      1.000000       0.666667     0.031631     0.460260
# 336      1.000000       0.666667     0.022656     0.455773
# 594      0.634805       0.628619     0.106949     0.406545
# 1106     0.661297       0.826095     0.000000     0.396565
# 1093     0.649714       0.780598     0.008262     0.396183
# 829      0.728218       0.652139     0.015863     0.390974
# 834      0.682675       0.680002     0.014256     0.383407
# 1085     0.619362       0.686193     0.082595     0.378557
# 1018     0.654049       0.648501     0.029443     0.377313
# 973      0.540661       0.820950     0.056779     0.373991
# 569      0.741123       0.646240     0.000000     0.373727
# 257      0.403414       0.854248     0.000000     0.370344
# 1047     0.519494       0.869168     0.020446     0.370000
# 161      0.618829       0.594657     0.061404     0.368283
# 806      0.673370       0.654004     0.014605     0.367198

# %%
ui3 = cbr.user_info()
ex3 = cbr.get_total_score()
ex3
# Out:
# --------------------------------------------------------------------
# 노래를 추천해드리기 전에 잠시 당신에 대해서 알아보겠습니다
# --------------------------------------------------------------------
# 무슨 곡이 가장 좋아요?   1) Fighting! 응원해  2) Breath  3) You’re the Best  4) DORADORA  5) Yo No Soy Celoso
# Breath
# 어떤 분위기의 곡을 좋아하세요?   1) 밝은  2) 어두운
# 1
# 어느정도의 속도를 가직 곡을 좋아하시나요?   1) 빠름  2) 느림
# 1
# 고객님께서는 현재 감정이 어떤 상태이신가요?   1) 신남  2) 평범  3) 슬픔
# 2
#           artist_name          track_name                          album_name  \
# 490             Beast              Breath                            So Beast
# 493             Beast           Beautiful                            So Beast
# 497             Beast             Mystery                   Beast Is The B2ST
# 495             Beast            Bad Girl                   Beast Is The B2ST
# 488             Beast     Beautiful Night                        Midnight Sun
# 479               2PM        우리집 My House                                No.5
# 491             Beast              Shadow           Hard to love, How to love
# 189               AOA          Like a Cat                          Like a Cat
# 760               EXO               3.6.5    The 1st Album 'XOXO' (Repackage)
# 290           BIGBANG          Dirty Cash                      BIGBANG Vol. 1
# 80             Secret        Love Is Move                    MOVING IN SECRET
# 6                 BTS         Yet To Come                               Proof
# 857               BoA          My Sweetie                No.1 - The 2nd Album
# 782           SHINHWA               Venus                          The Return
# 494             Beast               Shock                Shock Of The New Era
# 455  SUPER JUNIOR-D&E  떴다 오빠 (Oppa, Oppa)  'The Beat Goes On' Special Edition
# 349         SECHSKIES              Couple                             Special
# 204        Girl's Day        Ring My Bell        Girl's Day Love Second Album
# 496             Beast            Midnight                            Midnight
# 68             Secret             Shy Boy                             Shy Boy
#
#      mood_score  speed_score  emotion_score  genre_score  total_score
# 490       0.479     0.615234       0.662823     1.000000     0.792843
# 493       0.916     0.658336       0.702992     0.597603     0.678356
# 497       0.948     0.624923       0.691019     0.399088     0.576868
# 495       0.902     0.601051       0.642679     0.389286     0.552265
# 488       0.685     0.591308       0.710551     0.261909     0.462098
# 479       0.781     0.845995       0.636607     0.150518     0.452526
# 491       0.752     0.552306       0.609690     0.264885     0.451442
# 189       0.928     0.962276       0.661476     0.044638     0.447611
# 760       0.930     0.629816       0.655035     0.145728     0.442006
# 290       0.947     0.624409       0.706758     0.118684     0.439036
# 80        0.963     0.773430       0.746140     0.049885     0.438704
# 6         0.683     0.826808       0.699394     0.132724     0.434562
# 857       0.923     0.932434       0.691953     0.017267     0.433198
# 782       0.821     0.605530       0.649114     0.163616     0.427749
# 494       0.525     0.648656       0.706700     0.227817     0.427301
# 455       0.962     0.600695       0.747009     0.083361     0.426631
# 349       0.891     0.528804       0.630090     0.169723     0.426510
# 204       0.811     0.952116       0.668711     0.040806     0.425708
# 496       0.420     0.600791       0.683033     0.278345     0.423143
# 68        0.858     0.836296       0.587112     0.081711     0.421090
